# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/download.webp')

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/download.webp') #read an image

# Use cv2_imshow instead of cv2.imshow in Google Colab
cv2_imshow(img)
# cv2.waitkey(0) # Not needed with cv2_imshow in Colab
# cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
img = cv2.imread('/content/download.webp',0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=312x312>

# %%
img = cv2.imread('/content/download.webp',0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=312x312>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/download.webp')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

#Toh img[:, :, 0] → Blue channel
#img[:, :, 1] → Green channel
#img[:, :, 2] → Red channel

img[:,:,2]=0 # ka matlab hai: image ke har pixel ke Red channel ko 0 set kar do mtlb red coor ko hta rhe hai 
cv2_imshow(img)
cv2.waitKey(5000)   # Wait karo jab tak koi key press na ho
cv2.destroyAllWindows()        # Saari windows close karo
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/download.webp')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

img[:,:,0]=0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/download.webp')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

img[:,:,1]=0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
# Load the image in color mode (BGR is the default)
img = cv2.imread('/content/download.webp')

# Check if the image was loaded successfully
if img is not None:
    # Access and modify the blue channel (index 0 in BGR)
    img[:,:,0]=0
    cv2_imshow(img)
    # cv2.waitKey(0) # Not needed with cv2_imshow in Colab
    # cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
else:
    print("Error loading image.")
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
img = cv2.imread('/content/download.webp')

img = cv2.resize(img, (0, 0), fx=0.5, fy=0.5) #resize the image

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=156x156>

# %%
img = cv2.imread('/content/download.webp')
img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
img = cv2.rotate(img, cv2.ROTATE_180)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
cv2.imwrite('rotated_image.jpg', img)
# Out:
# True

# %%
cv2.imwrite('new_img.jpg', img)
# Out:
# True

# %%
print(img)

#BLUE GREEN RED  (RGB)
print(img)

#BLUE GREEN RED  (RGB)

[0,0,0]
[255, 252, 252]
[255, 252, 252]
# Out:
# [[[144 197 248]
#   [145 198 249]
#   [147 199 247]
#   ...
#   [ 21  44  70]
#   [ 23  46  72]
#   [ 15  38  64]]
#
#  [[144 197 248]
#   [145 198 249]
#   [147 199 247]
#   ...
#   [ 21  44  70]
#   [ 22  45  71]
#   [ 19  43  68]]
#
#  [[144 197 248]
#   [145 198 249]
#   [147 199 247]
#   ...
#   [ 29  52  78]
#   [ 19  43  68]
#   [ 25  48  74]]
#
#  ...
#
#  [[238 243 242]
#   [238 243 242]
#   [238 243 242]
#   ...
#   [238 242 244]
#   [238 242 244]
#   [238 242 244]]
#
#  [[238 243 242]
#   [238 243 242]
#   [238 243 242]
#   ...
#   [238 242 244]
#   [238 242 244]
#   [238 242 244]]
#
#  [[238 243 242]
#   [238 243 242]
#   [238 243 242]
#   ...
#   [238 242 244]
#   [238 242 244]
#   [238 242 244]]]
# [[[144 197 248]
#   [145 198 249]
#   [147 199 247]
#   ...
#   [ 21  44  70]
#   [ 23  46  72]
#   [ 15  38  64]]
#
#  [[144 197 248]
#   [145 198 249]
#   [147 199 247]
#   ...
#   [ 21  44  70]
#   [ 22  45  71]
#   [ 19  43  68]]
#
#  [[144 197 248]
#   [145 198 249]
# ...

# %%
imgBlue = img[:,:,0]
imgGreen = img[:,:,1]
imgRed = img[:,:,2]

new_img = np.hstack((imgBlue, imgGreen, imgRed))
cv2_imshow(new_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=936x312>
# -1

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np # Import numpy

# Load the image in color mode (BGR is the default)
img = cv2.imread('/content/download.webp',1)

# Check if the image was loaded successfully
if img is not None:
    # Split the image into its BGR channels
    imgBlue = img[:,:,0]
    imgGreen = img[:,:,1]
    imgRed = img[:,:,2]

    # Stack the channels horizontally
    new_img = np.hstack((imgBlue, imgGreen, imgRed))

    # Display the new image using cv2_imshow (suitable for Colab)
    cv2_imshow(new_img)
    # cv2.waitKey(0) # Not needed with cv2_imshow in Colab
    # cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
else:
    print("Error loading image.")
# Out:
# <PIL.Image.Image image mode=L size=936x312>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=312x312>

# %%
img_flip = cv2.flip(img, 2)

cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=312x312>

# %%
img_crop = img[100:300, 200:500]

cv2_imshow(img_crop)
# Out:
# <PIL.Image.Image image mode=RGB size=112x200>
