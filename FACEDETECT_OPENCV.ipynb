# %%
import cv2
from  google.colab.patches import cv2_imshow
from  google.colab import files
import urllib.request
from IPython.display import display,Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38c7f298-d736-4782-baa0-15a2e96d8417" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38c7f298-d736-4782-baa0-15a2e96d8417">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cascade_url = 'https://github.com/opencv/opencv/raw/master/data/haarcascades/haarcascade_frontalface_default.xml'
cascade_filename = 'haarcascade_frontalface_default.xml'
urllib.request.urlretrieve(cascade_url,cascade_filename)
# Out:
# ('haarcascade_frontalface_default.xml',
#  <http.client.HTTPMessage at 0x7d40afd011d0>)

# %%
#facecascade classifier
face_cascade = cv2.CascadeClassifier(cascade_filename)

# %%
img_path = 'Salman_Khan_in_2023_(1)_(cropped).jpg'

# %%
img =  cv2.imread(img_path)

# %%
if img is not None:
  gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray,1.1,4)

  for (x,y,w,h) in faces:
    cv2.rectangle(img ,  (x,y) ,  (x+w,y+h),(255,0,0),2)

  is_success,im_buf = cv2.imencode('.png',img)
  if is_success:
    display(Image(data=im_buf.tobytes()))
  else:
    print('error : imencode image for disply' )

else:
  print('error : could  not load image . check the file path')
